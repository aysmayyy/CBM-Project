# %%
import pandas as pd
data = pd.read_csv("../results/data/complete_ml_features.csv")
print(data.select_dtypes(include=['object']).columns.tolist())
# Out:
# ['first_careunit', 'last_careunit', 'intime', 'outtime', 'gender_x', 'gender_y', 'ethnicity']
