# %%
import pandas as pd

# Load d_items to see what these codes mean
d_items = pd.read_csv("../data/mimic-iv-3.1/icu/d_items.csv.gz")

# Find urine-related items
urine_items = d_items[d_items['label'].str.contains('urine|Urine', case=False, na=False)]
print("Urine-related items:")
print(urine_items[['itemid', 'label', 'category']])
# Out:
# Urine-related items:
#       itemid                         label                            category
# 112   220473                       Taurine  Ingredients - general (Not In Use)
# 161   220799     ZSpecific Gravity (urine)                                Labs
# 497   224015                  Urine Source                               GI/GU
# 498   224016                   Urine Color                               GI/GU
# 915   224876              Urine Appearance                               GI/GU
# 1310  225454                 Urine Culture                          6-Cultures
# 1883  226566     Urine and GU Irrigant Out                              Output
# 1934  226627                      OR Urine                              Output
# 1938  226631                    PACU Urine                              Output
# 2101  227059           UrineScore_ApacheIV              Scores - APACHE IV (2)
# 2232  227471      Specific Gravity (urine)                                Labs
# 2243  227489  GU Irrigant/Urine Volume Out                              Output
# 2249  227519         Urine output_ApacheIV              Scores - APACHE IV (2)
